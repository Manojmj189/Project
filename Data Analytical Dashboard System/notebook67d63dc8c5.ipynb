# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/scott-wastemanagement/Household waste generation 2022.csv
# /kaggle/input/scott-wastemanagement/Waste generation 2021.csv
# /kaggle/input/scott-wastemanagement/Waste landdfill 2021.csv
# /kaggle/input/scott-wastemanagement/Waste management 2022.csv
# /kaggle/input/scott-wastemanagement/Household waste generation 2021.csv
# /kaggle/input/scott-wastemanagement/Waste landdfill 2022.csv
# /kaggle/input/scott-wastemanagement/Waste generation 2022.csv
# /kaggle/input/scott-wastemanagement/Waste management 2021.csv

# %%
//importing library
import pandas as pd

# %%
//reading csv file 
management1=pd.read_csv('/kaggle/input/scott-wastemanagement/Waste management 2021.csv')
//displaying csv file
print(management1.head())
# Out:
#                           Waste type Disposed Recovered Recycled
# 0    Acid, alkaline or saline wastes      NaN        79      778
# 1        Animal and mixed food waste    2,275    12,154  300,295
# 2    Animal faeces, urine and manure       24    84,291   38,275
# 3  Batteries and accumulators wastes      NaN       NaN      532
# 4                    Chemical wastes    1,627       252      NaN

# %%
//reading csv file
management2=pd.read_csv('/kaggle/input/scott-wastemanagement/Waste management 2022.csv')
 //displaying csv file
print(management2.head())
# Out:
#                           Waste Type Disposed Recovered Recycled
# 0    Acid, alkaline or saline wastes       64        20      NaN
# 1        Animal and mixed food waste    1,985    17,745  320,935
# 2    Animal faeces, urine and manure       30    82,032   95,529
# 3  Batteries and accumulators wastes      NaN       NaN   10,052
# 4                    Chemical wastes    1,505       221      334

# %%
 //reading csv file
generation1=pd.read_csv('/kaggle/input/scott-wastemanagement/Waste generation 2021.csv')
//displaying csv file
print(generation1.head())
# Out:
#                           Waste type Commercial and industrial  \
# 0    Acid, alkaline or saline wastes                     5,446
# 1        Animal and mixed food waste                   264,622
# 2    Animal faeces, urine and manure                   112,594
# 3  Batteries and accumulators wastes                     9,223
# 4                    Chemical wastes                   109,313
#
#   Construction and demolition Household
# 0                         NaN       NaN
# 1                         NaN   100,462
# 2                         NaN       NaN
# 3                         NaN       562
# 4                         NaN       428

# %%
//reading csv file
generation2=pd.read_csv('/kaggle/input/scott-wastemanagement/Waste generation 2022.csv')
//displaying csv file
print(generation2.head())
# Out:
#                           Waste type Commercial and industrial  \
# 0    Acid, alkaline or saline wastes                     4,169
# 1        Animal and mixed food waste                   275,656
# 2    Animal faeces, urine and manure                   168,664
# 3  Batteries and accumulators wastes                    14,408
# 4                    Chemical wastes                   107,924
#
#   Construction and demolition Household
# 0                         NaN       NaN
# 1                         NaN    91,531
# 2                         NaN       NaN
# 3                         NaN       510
# 4                         NaN       327

# %%
//reading csv file
landfill1=pd.read_csv('/kaggle/input/scott-wastemanagement/Waste landdfill 2021.csv')
//displaying csv file
print(landfill1.head())
# Out:
#                         Waste type   2021  Unnamed: 2
# 0      Animal and mixed food waste  2,091         NaN
# 1  Animal faeces, urine and manure     24         NaN
# 2                  Chemical wastes    996         NaN
# 3                Combustion wastes  2,150         NaN
# 4                   Common sludges  3,188         NaN

# %%
//reading csv file 
landfill2=pd.read_csv('/kaggle/input/scott-wastemanagement/Waste landdfill 2022.csv')
//displaying csv file
print(landfill2.head())
# Out:
#                         Waste type   2022
# 0      Animal and mixed food waste  1,733
# 1  Animal faeces, urine and manure     30
# 2                  Chemical wastes    708
# 3                Combustion wastes  1,480
# 4                   Common sludges  3,247

# %%
//reading csv file
household1=pd.read_csv('/kaggle/input/scott-wastemanagement/Household waste generation 2021.csv')
//filtering top waste produing cities
cities1=['Aberdeen City','Aberdeenshire','City of Edinburgh','Dundee City','Falkirk','Fife','Glasgow City','Stirling','South Lanarkshire','North Lanarkshire','Highland']
filthouse1=household1[household1['Region'].isin(cities1)]
//displaying filtered region
print(filthouse1.head())
# Out:
#                Region   Tonnes  kg/person  Unnamed: 3
# 0       Aberdeen City   93,749        412         NaN
# 1       Aberdeenshire  117,503        447         NaN
# 4   City of Edinburgh  207,204        394         NaN
# 7         Dundee City   65,012        440         NaN
# 12            Falkirk   75,127        467         NaN

# %%
//reading csv file
household2=pd.read_csv('/kaggle/input/scott-wastemanagement/Household waste generation 2022.csv',encoding='utf-16-le',on_bad_lines='skip',sep='\t')
//filtering top waste producing cities 
cities2=['Aberdeen City','Aberdeenshire','City of Edinburgh','Dundee City','Falkirk','Fife','Glasgow City','Stirling','South Lanarkshire','North Lanarkshire','Highland']
filthouse2=household2[household2['Region'].isin(cities2)]
//displaying filtered region
print(filthouse2.head())
# Out:
#                Region    Tonnes  kg/person
# 0       Aberdeen City    88,802        396
# 1       Aberdeenshire  1,09,675        416
# 4   City of Edinburgh  1,87,628        366
# 7         Dundee City    60,499        409
# 12            Falkirk    64,308        406

# %%
//checking for duplicate values
manage1=management1.duplicated()
print(management1[manage1])
# Out:
# Empty DataFrame
# Columns: [Waste type, Disposed, Recovered, Recycled]
# Index: []

# %%
//checking for duplicate values 
manage2=management2.duplicated()
print(management2[manage2])
# Out:
# Empty DataFrame
# Columns: [Waste Type, Disposed, Recovered, Recycled]
# Index: []

# %%
//checking for duplicate values
gener1=generation1.duplicated()
print(generation1[gener1])
# Out:
# Empty DataFrame
# Columns: [Waste type, Commercial and industrial, Construction and demolition, Household]
# Index: []

# %%
//checking for duplicate values
gener2=generation2.duplicated()
print(generation2[gener2])
# Out:
# Empty DataFrame
# Columns: [Waste type, Commercial and industrial, Construction and demolition, Household]
# Index: []

# %%
//checking for duplicate values
land1=landfill1.duplicated()
print(landfill1[land1])
# Out:
# Empty DataFrame
# Columns: [Waste type, 2021, Unnamed: 2]
# Index: []

# %%
//checking for duplicate values
land2=landfill2.duplicated()
print(landfill2[land2])
# Out:
# Empty DataFrame
# Columns: [Waste type, 2022]
# Index: []

# %%
//checking for duplicate values
house1=household1.duplicated()
print(household1[house1])
# Out:
# Empty DataFrame
# Columns: [Region, Tonnes, kg/person, Unnamed: 3]
# Index: []

# %%
//checking for duplicate values
house2=household2.duplicated()
print(household2[house2])
# Out:
# Empty DataFrame
# Columns: [Region, Tonnes, kg/person]
# Index: []

# %%
filthouse1.to_csv("/kaggle/working/household generation 2021.csv",index=False)
filthouse2.to_csv("/kaggle/working/household generation 2022.csv",index=False)
